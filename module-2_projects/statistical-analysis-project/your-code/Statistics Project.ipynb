# %%
# import numpy and pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm

sns.set_style("ticks")

pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",100)

# %%
Train = pd.read_csv("train.csv")

# %%
Train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
Train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %% [markdown]
# ## 1. Analyse and explore the data set

# %%
# check for null value
Train.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# ...

# %%
# check individual columns for null values
Train.PoolQC.value_counts()
# Out:
# Gd    3
# Fa    2
# Ex    2
# Name: PoolQC, dtype: int64

# %%
Train.PoolArea.value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
Train.MiscFeature.value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
test = ["PoolQC","MiscFeature", "Alley","Fence","FireplaceQu","LotFrontage"]

for i in test:
    print(Train[i].value_counts())
# Out:
# Gd    3
# Fa    2
# Ex    2
# Name: PoolQC, dtype: int64
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 106.0      1
# 38.0       1
# 138.0      1
# 140.0      1
# 137.0      1
# Name: LotFrontage, Length: 110, dtype: int64

# %%
test1= ["BsmtExposure",  "BsmtFinType2",   "BsmtFinType1", "BsmtCond", "BsmtQual","MasVnrArea","MasVnrType","Electrical"] 



for i in test1:
    print(Train[i].value_counts())
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
# 0.0      861
# 72.0       8
# 180.0      8
# 108.0      8
# 120.0      7
#         ...
# 651.0      1
# 337.0      1
# 415.0      1
# 293.0      1
# 621.0      1
# Name: MasVnrArea, Length: 327, dtype: int64
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
corrmat = Train.corr()
f, ax = plt.subplots(figsize=(15,12))
sns.heatmap(corrmat, vmax=1, vmin=-1, center=0,
             cmap=sns.diverging_palette(20, 220, n=200));

# %% [markdown]
# Garage

# %%
Train[Train.GarageCond.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 78      79          90       RL         72.0    10778   Pave   NaN      Reg
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 89      90          20       RL         60.0     8070   Pave   NaN      Reg
# 99     100          20       RL         77.0     9320   Pave   NaN      IR1
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 125    126         190       RM         60.0     6780   Pave   NaN      Reg
# 127    128          45       RM         55.0     4388   Pave   NaN      IR1
# 140    141          20       RL         70.0    10500   Pave   NaN      Reg
# 148    149          20       RL         63.0     7500   Pave   NaN      Reg
# ...

# %%
Train[Train.GarageArea==0].GarageArea.value_counts()
# Out:
# 0    81
# Name: GarageArea, dtype: int64

# %% [markdown]
# Fireplace

# %%
Train.Fireplaces.value_counts()

## We can conclude that when there is no fireplace, naturally the FireplaceQu (Fireplace Quality) would be missing.
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %% [markdown]
# ## 2. Null value analysis- Consolidated Summary
#
# We can see the reason behind null values.
#
# For the columns in "PoolQC","MiscFeature", "Alley","Fence","FireplaceQu","LotFrontage",
# we can see that the existence of null values are due to the lack of the particular feature in the corresponding house/property and its vicinity.
#
# For the 4 columns related to Garage, the row returns Null Value when the house/property does not have a garage.
#
# ## Decision
#
# Dropping the following columns due to insufficient and irrelevant data.
# -Id
#
# -PoolQC
#
# -MiscFeature
#
# -Alley
#
#
# Columns to be combined or transformed to a boolean value
#
# -Fence
#
# -Fireplaces & FireplaceQu

# %% [markdown]
# ## Drop columns

# %%
col_to_drop = ["Id","PoolQC","PoolArea","MiscFeature","Alley"]

# %%
Train = Train.drop(columns=col_to_drop)

# %%
Train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# ## 3. Further analysis on column dropping

# %%
Train[Train.Electrical.isnull()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 1379          80       RL         73.0     9735   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# 1379    AllPub    Inside       Gtl       Timber       Norm       Norm
#
#      BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1379     1Fam       SLvl            5            5       2006          2007
#
#      RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea  \
# 1379     Gable  CompShg     VinylSd     VinylSd       None         0.0
#
#      ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 1379        TA        TA      PConc       Gd       TA           No
#
#      BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 1379          Unf           0          Unf           0        384
#
#       TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# ...

# %%
Train.Electrical.value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
Train.GarageCars.value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
Train.Heating.value_counts()/1460
# Out:
# GasA     0.978082
# GasW     0.012329
# Grav     0.004795
# Wall     0.002740
# OthW     0.001370
# Floor    0.000685
# Name: Heating, dtype: float64

# %%
Train.KitchenAbvGr.value_counts()/1460
# Out:
# 1    0.953425
# 2    0.044521
# 3    0.001370
# 0    0.000685
# Name: KitchenAbvGr, dtype: float64

# %%
## drop Electrical as there is mainly only one type of electrical system
Electrical_to_drop =["Electrical"]
Train = Train.drop(columns=Electrical_to_drop)
## drop ALL garage columns besides GarageCars as our main concern is how many cars can be parked in the garage
Garage_to_drop=["GarageType","GarageYrBlt","GarageFinish","GarageArea","GarageQual","GarageCond"]
Train = Train.drop(columns=Garage_to_drop)
## drop Heating as majority of the type of heating is GasA (98% of them)
Heating_to_drop=["Heating"]
Train = Train.drop(columns=Heating_to_drop)
## drop KitchenAbvGr as majority of the number of the kitchen is 1 (95% of them)
Kitchen_to_drop =["KitchenAbvGr"]
Train = Train.drop(columns=Kitchen_to_drop)
## drop Central

# %%
#check the number of null value again

Train.isnull().sum().sort_values(ascending=False)
# Out:
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# BsmtFinType2       38
# BsmtExposure       38
# BsmtCond           37
# BsmtQual           37
# BsmtFinType1       37
# MasVnrArea          8
# MasVnrType          8
# Street              0
# YearBuilt           0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearRemodAdd        0
# OverallCond         0
# LotArea             0
# OverallQual         0
# BldgType            0
# Condition2          0
# MSZoning            0
# Condition1          0
# Neighborhood        0
# LandSlope           0
# LotConfig           0
# Utilities           0
# LandContour         0
# LotShape            0
# HouseStyle          0
# SalePrice           0
# BsmtFinSF1          0
# SaleCondition       0
# SaleType            0
# YrSold              0
# MoSold              0
# MiscVal             0
# ...

# %% [markdown]
# ## Replacing the remaining NaN values

# %%
## Replace NaN to "NA"

Train.Fence = Train.Fence.fillna("NA")
Train.FireplaceQu = Train.FireplaceQu.fillna("NA")
Train.BsmtFinType2 = Train.BsmtFinType2.fillna("NA")
Train.BsmtExposure = Train.BsmtExposure.fillna("NA")
Train.BsmtCond = Train.BsmtCond.fillna("NA")
Train.BsmtQual = Train.BsmtQual.fillna("NA")
Train.BsmtFinType1 = Train.BsmtFinType1.fillna("NA")


## Replace NaN to 0

Train.LotFrontage=Train.LotFrontage.fillna(0)

# %% [markdown]
# ## 4. Categorical to numerical value conversion

# %%
Train.select_dtypes(include="object")
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# ...

# %%
# Convert the below columns from categorical to numerical

Train = Train.replace({"BsmtCond" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "BsmtExposure" : {"NA" : 0,"No": 0, "Mn" : 1, "Av": 2, "Gd" : 3},
                       "BsmtFinType1" : {"NA" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtFinType2" : {"NA" : 0, "Unf" : 1, "LwQ": 2, "Rec" : 3, "BLQ" : 4, 
                                         "ALQ" : 5, "GLQ" : 6},
                       "BsmtQual" : {"NA" : 0, "Po" : 1, "Fa" : 2, "TA": 3, "Gd" : 4, "Ex" : 5},
                       "ExterCond" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "ExterQual" : {"Po" : 1, "Fa" : 2, "TA": 3, "Gd": 4, "Ex" : 5},
                       "Functional" : {"Sal" : 1, "Sev" : 2, "Maj2" : 3, "Maj1" : 4, "Mod": 5, 
                                       "Min2" : 6, "Min1" : 7, "Typ" : 8},
                       "HeatingQC" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "KitchenQual" : {"Po" : 1, "Fa" : 2, "TA" : 3, "Gd" : 4, "Ex" : 5},
                       "LandSlope" : {"Sev" : 1, "Mod" : 2, "Gtl" : 3},
                       "LotShape" : {"IR3" : 1, "IR2" : 2, "IR1" : 3, "Reg" : 4},
                       "PavedDrive" : {"N" : 0, "P" : 1, "Y" : 2},
                       "Street" : {"Grvl" : 1, "Pave" : 2},
                       "Utilities" : {"ELO" : 1, "NoSeWa" : 2, "NoSewr" : 3, "AllPub" : 4},
                      "Fence":{"NA":0,"MnWw":1, "GdWo":2,"MnPrv":3,"GdPrv":4}})

# %%
Train.Fence.value_counts()
# Out:
# 0    1179
# 3     157
# 4      59
# 2      54
# 1      11
# Name: Fence, dtype: int64

# %%
Train.CentralAir.value_counts()
# Out:
# Y    1365
# N      95
# Name: CentralAir, dtype: int64

# %%
# Convert the below columns into a boolean as majority of the values in these columns are 

Train['MSZoning'] = (Train['MSZoning'] == 'RL').astype(int)
Train['LandContour'] = (Train['LandContour'] == 'Lvl').astype(int)
Train['LotConfig'] = (Train['LotConfig'] == 'Inside').astype(int)
Train['Condition1'] = (Train['Condition1'] == 'Norm').astype(int)
Train['Condition2'] = (Train['Condition2'] == 'Norm').astype(int)
Train['BldgType'] = (Train['BldgType'] == '1Fam').astype(int)
Train['RoofStyle'] = (Train['RoofStyle'] == 'Gable').astype(int)
Train['RoofMatl'] = (Train['RoofMatl'] == 'CompShg').astype(int)
Train['CentralAir'] = (Train['CentralAir'] == 'Y').astype(int)
Train['SaleType'] = (Train['SaleType'] == 'WD').astype(int)
Train['SaleCondition'] = (Train['SaleCondition'] == 'Normal').astype(int)

# %%
## Manually changing one specific column to a int datatype

Train.BsmtCond = Train.BsmtCond.astype("str").astype("int")

# %%
Train.select_dtypes(include="object")
# Out:
#      Neighborhood HouseStyle Exterior1st Exterior2nd MasVnrType Foundation  \
# 0         CollgCr     2Story     VinylSd     VinylSd    BrkFace      PConc
# 1         Veenker     1Story     MetalSd     MetalSd       None     CBlock
# 2         CollgCr     2Story     VinylSd     VinylSd    BrkFace      PConc
# 3         Crawfor     2Story     Wd Sdng     Wd Shng       None     BrkTil
# 4         NoRidge     2Story     VinylSd     VinylSd    BrkFace      PConc
# ...           ...        ...         ...         ...        ...        ...
# 1455      Gilbert     2Story     VinylSd     VinylSd       None      PConc
# 1456       NWAmes     1Story     Plywood     Plywood      Stone     CBlock
# 1457      Crawfor     2Story     CemntBd     CmentBd       None      Stone
# 1458        NAmes     1Story     MetalSd     MetalSd       None     CBlock
# 1459      Edwards     1Story     HdBoard     HdBoard       None     CBlock
#
#      FireplaceQu
# 0             NA
# 1             TA
# ...

# %%
Train.BsmtExposure.value_counts()
# Out:
# 0    991
# 2    221
# 3    134
# 1    114
# Name: BsmtExposure, dtype: int64

# %%
corr = Train.corrwith(Train['SalePrice'])

# %%
corr = corr.sort_values(ascending=False)

# %%
corr
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# ExterQual        0.682639
# KitchenQual      0.659600
# GarageCars       0.640409
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# BsmtQual         0.585207
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# Fireplaces       0.466929
# HeatingQC        0.427649
# BsmtFinSF1       0.386420
# BsmtExposure     0.361863
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# BsmtFinType1     0.304908
# HalfBath         0.284108
# LotArea          0.263843
# CentralAir       0.251328
# MSZoning         0.245063
# PavedDrive       0.231357
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BsmtCond         0.212607
# LotFrontage      0.209624
# BedroomAbvGr     0.168213
# BldgType         0.137483
# Condition1       0.112968
# ScreenPorch      0.111447
# ...

# %% [markdown]
# ## 5. Statistical Analysis

# %%
Train1 =Train.copy()

# %%
# add constant column to train2 dataframe:

Train1 = sm.add_constant(Train1)

# run OLS on 'SalePrice' as dependent variable and top 10:

SalePrice_corr = sm.OLS(Train1["SalePrice"],
               Train1[["const", 
                       "OverallQual", 
                       "GrLivArea", 
                       "ExterQual", 
                       "KitchenQual", 
                       "GarageCars", 
                       "TotalBsmtSF",
                       "1stFlrSF",
                       "BsmtQual",
                       "FullBath",
                       "TotRmsAbvGrd",
                      "Fence",
                      "SaleCondition",
                      "RoofStyle",
                      "SaleType",
                      "LotShape"]]).fit()

"""
OverallQual      0.790982
GrLivArea        0.708624
ExterQual        0.682639
KitchenQual      0.659600
GarageCars       0.640409
TotalBsmtSF      0.613581
1stFlrSF         0.605852
BsmtQual         0.585207
FullBath         0.560664
TotRmsAbvGrd     0.533723
YearBuilt        0.522897
YearRemodAdd     0.507101
MasVnrArea       0.477493
Fireplaces       0.466929
HeatingQC        0.427649
BsmtFinSF1       0.386420
BsmtExposure     0.361863
"""

print('Parameters:' ,"\n", SalePrice_corr.params, "\n")

print('R2: ', SalePrice_corr.rsquared)
# Out:
# Parameters:
#  const           -116156.523569
# OverallQual       14003.787789
# GrLivArea            44.982102
# ExterQual         13427.029344
# KitchenQual       14821.273836
# GarageCars        13335.211347
# TotalBsmtSF           5.526245
# 1stFlrSF             21.099549
# BsmtQual           9243.538044
# FullBath          -3072.166514
# TotRmsAbvGrd          8.396273
# Fence               -99.775615
# SaleCondition      4699.477429
# RoofStyle        -10428.217803
# SaleType          -8811.854685
# LotShape          -6567.327658
# dtype: float64
#
# R2:  0.7916375364788845

# %%
SalePrice_corr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     365.7
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):               0.00
# Time:                        20:29:35   Log-Likelihood:                -17399.
# No. Observations:                1460   AIC:                         3.483e+04
# Df Residuals:                    1444   BIC:                         3.491e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Summary
#
# 15 variables (including the top 10 positively correlated and top 5 negatively correlated to the sale price) were selected and a linear regression analysis was then performed.
#
# Of those 15 variables, it was found that __7 out of the 10__ positively correlated and __3 out of 5__ negatively correlated variables have sufficient statistical evidence to prove their correlation to the sale price are not merely due to randomness factors.
#
# To conclude, while variables such as Kitchen Quality and Exterior Quality can pose as significant positive influence (the higher the rating/score, the higher the sale price) on the final sale price. A binomial approach on roof style found that the Gable roof style poses the highest negative effect on the sale price in comparison on the other factors.
