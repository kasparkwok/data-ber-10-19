# %%
# import libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
NBA_team = pd.read_csv("nba_team_stats_80_to_18.csv")

# %%
import re
year_pattern = "(20)(\d{2}-)(\d{2})"

for line in NBA_team["YEAR"]:
    print(line)
# Out:
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2018-19
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2017-18
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2016-17
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# 2015-16
# ...

# %%
# Convert season into year using regex 
NBA_team['YEAR'] = NBA_team['YEAR'].str.replace(r'(20)(\d{2}-)', '20')

# %%
NBA_team
# Out:
#      Unnamed: 0                 TEAM  GP   W   L   WIN%   MIN    PTS   FGM  \
# 0             0        Atlanta Hawks  82  29  53  0.354  48.4  113.3  41.4
# 1             1       Boston Celtics  82  49  33  0.598  48.2  112.4  42.1
# 2             2        Brooklyn Nets  82  42  40  0.512  48.7  112.2  40.3
# 3             3    Charlotte Hornets  82  39  43  0.476  48.4  110.7  40.2
# 4             4        Chicago Bulls  82  22  60  0.268  48.5  104.9  39.8
# ..          ...                  ...  ..  ..  ..    ...   ...    ...   ...
# 561         561  Seattle SuperSonics  82  44  38  0.537  48.3   97.3  36.9
# 562         562      Toronto Raptors  82  47  35  0.573  48.7   97.6  37.2
# 563         563            Utah Jazz  82  53  29  0.646  48.2   97.1  36.1
# 564         564  Vancouver Grizzlies  82  23  59  0.280  48.2   91.7  35.0
# 565         565   Washington Wizards  82  19  63  0.232  48.0   93.2  34.5
#
# ...

# %%
#Convert 
NBA_team["YEAR"] =  NBA_team["YEAR"].astype("int")

# %%
NBA_team.dtypes
# Out:
# Unnamed: 0      int64
# TEAM           object
# GP              int64
# W               int64
# L               int64
# WIN%          float64
# MIN           float64
# PTS           float64
# FGM           float64
# FGA           float64
# FG%           float64
# 3PM           float64
# 3PA           float64
# 3P%           float64
# FTM           float64
# FTA           float64
# FT%           float64
# OREB          float64
# DREB          float64
# REB           float64
# AST           float64
# TOV           float64
# STL           float64
# BLK           float64
# BLKA          float64
# PF            float64
# PFD           float64
# +/-           float64
# SEASON         object
# YEAR            int32
# dtype: object

# %%
NBA_team.to_csv("NBA team 2001 to 2019.csv")

# %%
NBA_team_playoffs = pd.read_csv("Book4.csv")

# %%
NBA
# Out:
# Year         int64
# Series      object
# Winner      object
# W            int64
# Loser       object
# W.1          int64
# Favorite    object
# Underdog    object
# dtype: object
